# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd


x317 = []
y317 = []

x325 = []
y325 = []

x340 = []
y340 = []

x388 = []
y388 = []

x443 = []
y443 = []

x551 = []
y551 = []

x680 = []
y680 = []

x688 = []
y688 = []

x764 = []
y764 = []

x780 = []
y780 = []

df=pd.read_csv('lightcurves_original.csv', sep=',',header=None)


for row in df:
    x317.append(df[0][row])
    y317.append(df[1][row])
    
    x325.append(df[0][row])
    y325.append(df[2][row])
    
    x340.append(df[0][row])
    y340.append(df[3][row])
    
    x388.append(df[0][row])
    y388.append(df[4][row])
    
    x443.append(df[0][row])
    y443.append(df[5][row])
    
    x551.append(df[0][row])
    y551.append(df[6][row])
    
    x680.append(df[0][row])
    y680.append(df[7][row])
    
    x688.append(df[0][row])
    y688.append(df[8][row])
    
    x764.append(df[0][row])
    y764.append(df[9][row])
    
    x780.append(df[0][row])
    y780.append(df[10][row])


# 317 nm
plt.plot(x317, y317)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (317 nm)')
plt.show()

# 325 nm
plt.plot(x325, y325)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (325 nm)')
plt.show()

# 340 nm
plt.plot(x340, y340)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (340 nm)')
plt.show()

# 388 nm
plt.plot(x388, y388)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (388 nm)')
plt.show()

# 443 nm
plt.plot(x443, y443)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (443 nm)')
plt.show()

# 551 nm
plt.plot(x551, y551)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (551 nm)')
plt.show()

# 680 nm
plt.plot(x680, y680)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (680 nm)')
plt.show()

# 688 nm
plt.plot(x688, y688)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (688 nm)')
plt.show()

# 764 nm
plt.plot(x764, y764)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (764 nm)')
plt.show()

# 780 nm
plt.plot(x780, y780)
plt.xlabel('Timestamps')
plt.ylabel('Reflectance value')
plt.title('Reflectance values vs Timestamps (780 nm)')
plt.show()
